# %% [markdown]
# # Multi-Variable Linear Regression

# %% [markdown]
# - 이전 Lec # 1 의 선형 회귀에서는 결과값에 영향을 미치는 변수가 1개
# - Multi-variable linear regression 에서는 변수(x)가 둘 이상일 때의 선형 회귀

# %% [markdown]
# ## 1. Data

# %% [markdown]
# ![image.png](attachment:image.png)
# - 이처럼 결과값에 영향을 미치는 변수가 x1, x2, x3 로 이루어진 데이터가 있을 수 있다

# %% [markdown]
# ## 2. Hypothesis

# %% [markdown]
# - 이전의 경우, 변수가 하나이므로, Hypothesis 를 아래와 같은 식으로 표현했다
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 하지만 변수가 둘 이상일 경우, Hypothesis 는 아래와 같은 식으로 표현된다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Cost Function

# %% [markdown]
# - 따라서, Cost Function 은 아래와 같은 식으로 표현된다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. Matrix

# %% [markdown]
# ![image.png](attachment:image.png)
# - 하지만, 변수의 개수가 늘어날수록 식이 길어져 연산이 복잡해지는 결과가 발생한다
# - 따라서 우리는 행렬을 활용하여 간단하게 다음과 같이 나타낼 수 있다
#
# ![image-2.png](attachment:image-2.png)
#
# - 행렬의 곱으로 연산한 결과가 이와 같으므로, 위 식이 성립한다
# - 결국 변수의 개수가 많을 때, 우리는 행렬을 활용하여 아래와 같이 나타낸다
#
# ![image-3.png](attachment:image-3.png)
#
# - 행렬의 곱은 순서에 따라 결과값이 달라지지만, 구현 시 편의상 X 를 앞에 배치
# - 수학적으로 결과의 값에 차이가 없다

# %% [markdown]
# ##### n 개의 instance 와 m 개의  Variables 를 가진 Data

# %% [markdown]
# - 위 개념을 확장하여 우리는 여러 개의 변수에 여러개의 instance 를 가진 데이터를 표현할 수 있다
#
# ![image.png](attachment:image.png)
# - n 은 instance 의 수, m 은 variables 의 수
# - x(nm) 행렬과 W(m) 행렬의 곱으로 나타낸다
